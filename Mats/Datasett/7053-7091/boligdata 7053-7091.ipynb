# %%
import pandas as pd
# Out:
# c:\Users\MatsN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
liste1 = pd.read_excel('Ny liste (18) 29-02-24.xlsx')
liste2 = pd.read_excel('Ny liste (39) 29-02-24.xlsx')
liste3 = pd.read_excel('Ny liste (40) 29-02-24 (1).xlsx')
liste4 = pd.read_excel('Ny liste (49) 29-02-24.xlsx')
liste5 = pd.read_excel('Ny liste (71) 29-02-24.xlsx')
liste6 = pd.read_excel('Ny liste (103) 29-02-24.xlsx')
liste7 = pd.read_excel('Ny liste (109) 29-02-24.xlsx')
liste8 = pd.read_excel('Ny liste (173) 29-02-24 (1).xlsx')
liste9 = pd.read_excel('Ny liste (176) 29-02-24.xlsx')
liste10 = pd.read_excel('Ny liste (193) 29-02-24.xlsx')
liste11 = pd.read_excel('Ny liste (231) 29-02-24 (1).xlsx')
liste12 = pd.read_excel('Ny liste (236) 29-02-24.xlsx')
liste13 = pd.read_excel('Ny liste (246) 29-02-24.xlsx')

liste14 = pd.read_excel('Ny liste (251) 29-02-24.xlsx')
liste15 = pd.read_excel('Ny liste (281) 29-02-24.xlsx')
liste16 = pd.read_excel('Ny liste (301) 29-02-24.xlsx')
liste17 = pd.read_excel('Ny liste (325) 29-02-24 (1).xlsx')
liste18 = pd.read_excel('Ny liste (345) 29-02-24 (1).xlsx')
liste19 = pd.read_excel('Ny liste (347) 29-02-24.xlsx')
liste20 = pd.read_excel('Ny liste (361) 29-02-24.xlsx')
liste21 = pd.read_excel('Ny liste (365) 29-02-24.xlsx')
liste22 = pd.read_excel('Ny liste (372) 29-02-24.xlsx')
liste23 = pd.read_excel('Ny liste (390) 29-02-24.xlsx')
liste24 = pd.read_excel('Ny liste (392) 29-02-24.xlsx')
liste25 = pd.read_excel('Ny liste (414) 29-02-24.xlsx')
liste26 = pd.read_excel('Ny liste (427) 29-02-24.xlsx')
liste27 = pd.read_excel('Ny liste (435) 29-02-24.xlsx')
liste28 = pd.read_excel('Ny liste (498) 29-02-24.xlsx')

# %%
file_path = [liste1, liste2, liste3, liste4, liste5, liste6, liste7, liste8, liste9, liste10,
liste11, liste12, liste13, liste14, liste15, liste16, liste17, liste18, liste19, liste20,
liste21, liste22, liste23, liste24, liste25, liste26, liste27, liste28]

# %%
combined_data = pd.concat(file_path, ignore_index=True)

# %%
combined_data
# Out:
#      Matrikkel / Org-Anr                                   Adresse  \
# 0         5001-38/58/0/0      Øvre Vikaraunet 6 A, 7057 JONSVATNET
# 1         5001-37/59/0/0         Røstadbakken 162, 7057 JONSVATNET
# 2          5001-37/5/0/0         Røstadbakken 145, 7057 JONSVATNET
# 3         5001-29/27/0/0       Jonsvannsveien 585, 7057 JONSVATNET
# 4        5001-37/134/0/0         Røstadbakken 189, 7057 JONSVATNET
# ...                  ...                                       ...
# 7183         986881433/1      Østersunds gate 13 B, 7067 TRONDHEIM
# 7184   5001-411/201/0/37      Anders Buens gate 17, 7067 TRONDHEIM
# 7185    5001-411/204/0/0  Lademoens Kirkealle 11 B, 7067 TRONDHEIM
# 7186   5001-411/170/0/29          Mellomveien 18 B, 7067 TRONDHEIM
# 7187   5001-411/110/0/94      Innherredsveien 86 A, 7067 TRONDHEIM
#
#                  Boligtype   Prom    BRA    BTA  Byggeår  Etasje Balkong  \
# 0        Selveier enebolig  237.0  272.0    NaN   1950.0     NaN      Ja
# ...

# %%
combined_data.to_excel("combined7053-7091.xlsx", index=False)
