# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# c:\Users\MatsN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_excel("boligm_info.xlsx")

# %%
df = df.drop("Boliger i alt", axis=1)

# %%
df.head(1)
# Out:
#    Unnamed: 1  Prisindeks for brukte boliger  Boligendring   KPI  Endring KPI  \
# 0        2002                            0.0           NaN  78.7          NaN
#
#    Styringsrente  Styringsrente.1  Endring Styringsrente
# 0           6.73           0.0673                    0.0

# %%
df.rename(columns={'Unnamed: 1': 'Year'}, inplace=True)
df.rename(columns={'Prisindeks for brukte boliger': 'Housing Price Index Trondheim'}, inplace=True)
df.rename(columns={'Boligendring': 'Change in Housing price index'}, inplace=True)
df.rename(columns={'KPI': 'Consumer Price Index'}, inplace=True)
df.rename(columns={'Endring KPI': 'Change Consumer Price Index'}, inplace=True)
df.rename(columns={'Styringsrente': 'Policy Rate %'}, inplace=True)
df.rename(columns={'Styringsrente.1': 'Policy Rate'}, inplace=True)
df.rename(columns={'Endring Styringsrente': 'Change Policy Rate'}, inplace=True)

# %%
df = df[4:]
df = df.reset_index(drop=True)

# %%
max_year = df['Year'].max()

# Calculate the starting year for the last ten years
starting_year = max_year - 10

# Filter the DataFrame to include only data from the last ten years
df = df[df['Year'] >= starting_year]

# %%
df.head(1)
# Out:
#    Year  Housing Price Index Trondheim  Change in Housing price index  \
# 7  2013                           91.7                       0.055616
#
#    Consumer Price Index  Change Consumer Price Index  Policy Rate %  \
# 7                  95.9                     0.020855            1.5
#
#    Policy Rate  Change Policy Rate
# 7        0.015             -0.0005

# %%
# Plot the line plot
ax = df.plot(x='Year', y=['Housing Price Index Trondheim', 'Consumer Price Index'], kind='line')

ax.set_xticks(df['Year'])

# Set the labels and title
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Housing price index and Consumer price index')
plt.xticks(rotation=45)

# Show the plot
plt.grid(True, alpha = 0.2)
plt.legend()
plt.show()

# %%
# Plot the line plot
ax = df.plot(x='Year', y=['Change in Housing price index', 'Policy Rate'], kind='line')

ax.set_xticks(df['Year'])

# Set the labels and title
plt.xlabel('Year')
plt.title('Housing Price Index and Policy Rate')
plt.xticks(rotation=45)

# Show the plot
plt.grid(True, alpha = 0.2)
plt.legend()
plt.show()
