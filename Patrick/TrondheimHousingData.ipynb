# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_excel('TrondheimHousingData(Usortert).xlsx')
data
# Out:
#       Matrikkel / Org-Anr                                Adresse  \
# 0        5001-400/93/0/12  Erling Skakkes gate 1, 7013 TRONDHEIM
# 1        5001-400/123/0/3        Vår Frue gate 8, 7013 TRONDHEIM
# 2        5001-400/102/0/5         Schultz gate 8, 7013 TRONDHEIM
# 3        5001-400/93/0/10  Erling Skakkes gate 1, 7013 TRONDHEIM
# 4        5001-400/123/0/5        Vår Frue gate 8, 7013 TRONDHEIM
# ...                   ...                                    ...
# 21522    5001-521/491/0/4             Nordalsvegen 3, 7540 KLÆBU
# 21523    5001-520/121/0/9           Stormyrvegen 8 A, 7540 KLÆBU
# 21524     5001-520/53/0/3          Torvmarkvegen 6 A, 7540 KLÆBU
# 21525   5001-521/519/0/10             Granmovegen 18, 7540 KLÆBU
# 21526    5001-521/263/0/0             Skjoldvegen 10, 7540 KLÆBU
#
#                Boligtype   Prom    BRA    BTA  Byggeår  Etasje Balkong  \
# 0      Selveierleilighet   40.0   40.0   40.0   1974.0     2.0      Ja
# ...

# %%
data.drop(columns=['Hjemmelshaver'], inplace=True)

# %%
data['Postnummer'] = data['Adresse'].str.split(', ').str[1].str[:4].astype(int)
data
# Out:
#       Matrikkel / Org-Anr                                Adresse  \
# 0        5001-400/93/0/12  Erling Skakkes gate 1, 7013 TRONDHEIM
# 1        5001-400/123/0/3        Vår Frue gate 8, 7013 TRONDHEIM
# 2        5001-400/102/0/5         Schultz gate 8, 7013 TRONDHEIM
# 3        5001-400/93/0/10  Erling Skakkes gate 1, 7013 TRONDHEIM
# 4        5001-400/123/0/5        Vår Frue gate 8, 7013 TRONDHEIM
# ...                   ...                                    ...
# 21522    5001-521/491/0/4             Nordalsvegen 3, 7540 KLÆBU
# 21523    5001-520/121/0/9           Stormyrvegen 8 A, 7540 KLÆBU
# 21524     5001-520/53/0/3          Torvmarkvegen 6 A, 7540 KLÆBU
# 21525   5001-521/519/0/10             Granmovegen 18, 7540 KLÆBU
# 21526    5001-521/263/0/0             Skjoldvegen 10, 7540 KLÆBU
#
#                Boligtype   Prom    BRA    BTA  Byggeår  Etasje Balkong  \
# 0      Selveierleilighet   40.0   40.0   40.0   1974.0     2.0      Ja
# ...

# %%
data['Registrert dato'] = pd.to_datetime(data['Registrert dato'][0], format='%d/%m/%Y')
data['Sist solgt'] = pd.to_datetime(data['Sist solgt'][0], format='%d/%m/%Y')

# %%
data.head()
# Out:
#   Matrikkel / Org-Anr                                Adresse  \
# 0    5001-400/93/0/12  Erling Skakkes gate 1, 7013 TRONDHEIM
# 1    5001-400/123/0/3        Vår Frue gate 8, 7013 TRONDHEIM
# 2    5001-400/102/0/5         Schultz gate 8, 7013 TRONDHEIM
# 3    5001-400/93/0/10  Erling Skakkes gate 1, 7013 TRONDHEIM
# 4    5001-400/123/0/5        Vår Frue gate 8, 7013 TRONDHEIM
#
#            Boligtype  Prom   BRA   BTA  Byggeår  Etasje Balkong Parkering  \
# 0  Selveierleilighet  40.0  40.0  40.0   1974.0     2.0      Ja       Nei
# 1  Selveierleilighet  49.0  49.0  54.0   1870.0     2.0     NaN       Nei
# 2  Selveierleilighet  53.0  53.0  58.0   1902.0     3.0      Ja       Nei
# 3  Selveierleilighet  46.0  46.0  50.0   1974.0     2.0     NaN       Nei
# 4  Selveierleilighet  42.0  42.0   NaN   1870.0     3.0     NaN       Nei
#
#    ...  Sist solgt     Pris Fellesgjeld ved siste salg  \
# 0  ...  20.12.2023  3100000                       0.00
# ...
